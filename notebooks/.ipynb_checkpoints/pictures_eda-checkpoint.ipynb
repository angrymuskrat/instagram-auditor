# %%
# %%capture
# %run ../img2vec/img2vec.py

# %%
import numpy as np
import pandas as pd
from pymongo import MongoClient
import base64

# %%
SERVER_IP = "213.136.94.240"
USERNAME = "admin"
PASSWORD = "04061997"

client = MongoClient(host=SERVER_IP, username=USERNAME, password=PASSWORD)

# %%
db = client.instagramAuditor

# %%
profiles = db.profiles

# %%
test_profiles = list(profiles.find().limit(2))

# %%
username = 'username'
fullname = 'fullname'
biography = 'biography'
followed_by = 'followedby'
follow = 'follow'
is_business_account = 'isbusinessaccount'
is_joined_recently = 'isjoinedrecently'
business_category_name = 'businesscategoryname'
business_category_name = 'categoryid'
is_private = 'isprivate'
is_verified = 'isverified'
has_connected_fb = 'connectedfbpage'
profile_pic = 'profilepic'
profile_pic_url = 'profilepicurl'
posts_count = 'postscount'
posts = 'posts'

# %%
def convert_to_img(raw):
    image_buf = io.BytesIO()
    base64.decode(io.StringIO(test_profile[profile_pic]), image_buf)
    return PIL.Image.open(image_buf)

# %%
img2vec = Image2Vec()

# %%
profile_embeddings = [profile[profile]]

# %%
convert_to_img(test_profile[profile_pic])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150 at 0x122124E50>
