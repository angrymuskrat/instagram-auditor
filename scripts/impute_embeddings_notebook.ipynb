# %%
from pymongo import MongoClient
import base64
import io
from PIL import Image
import sys
sys.path.insert(0, '../img2vec/')
from img2vec import Image2Vec
import threading
from time import time
import logging


username = 'username'
fullname = 'fullname'
biography = 'biography'
followed_by = 'followedby'
follow = 'follow'
is_business_account = 'isbusinessaccount'
is_joined_recently = 'isjoinedrecently'
business_category_name = 'businesscategoryname'
business_category_name = 'categoryid'
is_private = 'isprivate'
is_verified = 'isverified'
has_connected_fb = 'connectedfbpage'
profile_pic = 'profilepic'
profile_pic_url = 'profilepicurl'
posts_count = 'postscount'
posts = 'posts'
image = 'image'
profile_pic_embedding = 'profilepicembedding'
image_embedding = 'profilepicembedding'


def to_pil(raw):
    image_buf = io.BytesIO()
    base64.decode(io.StringIO(raw), image_buf)
    return Image.open(image_buf)


def extract_post_pics(profile):
    return [to_pil(post[image]) for post in profile[posts]]


def add_embeddings(img2vec, profile):
    if profile_pic in profile:
        profile[profile_pic_embedding] = img2vec.apply_single(to_pil(profile[profile_pic]))
    
    if posts in profile and len(profile[posts]) > 0:
        for post in profile[posts]:
            if image in post:
                post[image_embedding] = img2vec.apply_single(to_pil(post[image])).tolist()


def setup_logging():
    logger = logging.getLogger(__name__)
    logger.setLevel(logging.DEBUG)

    console_handler = logging.StreamHandler()
    console_handler.setLevel(logging.WARNING)

    file_handler = logging.FileHandler('instagramAuditor.log')
    file_handler.setLevel(logging.DEBUG)

    formatter = logging.Formatter('%(asctime)-15s - %(levelname)-5s - %(message)s')
    console_handler.setFormatter(formatter)
    file_handler.setFormatter(formatter)

    logger.addHandler(console_handler)
    logger.addHandler(file_handler)

    return logger


def setup_connection(logger):

    SERVER_IP = "213.136.94.240"
    USERNAME = "admin"
    PASSWORD = "04061997"

    client = MongoClient(host=SERVER_IP, username=USERNAME, password=PASSWORD)
    print("Client established")

    db = client.instagramAuditor
    profiles = db.profiles
    print("Collection retrieved")
    
    return profiles


def setup_img2vec(logger):
    img2vec = Image2Vec()
    print("Image2vec instance created")

    return img2vec


def vectorize_images(cursor, img2vec, logger):
    start_time = time()
    cnt = 0
    errors_in_profiles = []
    bulkList = []
    print("started")
    for profile in cursor.batch_size(200):
        try:
            print(cnt, "start")
            add_embeddings(img2vec, profile)
            print(cnt, "added_embeddings")
            bulkList.append(UpdateOne({'_id': profile['_id']}, 
                {'$set': {
                        profile_pic_embedding: profile[profile_pic_embedding].tolist(), 
                        posts: profile[posts]
                    }
                },
                upsert=True))
            #profiles.update_one({'_id': profile['_id']}, 
            #    {'$set': {
            #            profile_pic_embedding: profile[profile_pic_embedding].tolist(), 
            #            posts: profile[posts]
            #        }
            #    },
            #    upsert=True)
            print(cnt, "updated")
        except Exception as e:
            logger.exception(e)
            logger.debug("Profile: ", profile)
            errors_in_profiles.append(profile[username])
        finally:
            cnt += 1
            level = logging.WARNING if cnt % 100 == 0 else logging.DEBUG
            
            if(cnt % 100 == 0):
                print("executed bulk")
                result = profiles.bulk_write(bulkList)
                bulkList = []
            
            print(level, f"Total elapsed time: {time() - start_time}")
            print(level, f"Documents processed: {cnt}")
            


def for_each_profile(do, profiles, img2vec, logger):
    do(profiles.find(), img2vec, logger)


if __name__ == "__main__":
    logger = setup_logging()
    profiles = setup_connection(logger)
    img2vec = setup_img2vec(logger)

    for_each_profile(do=vectorize_images, profiles=profiles, img2vec=img2vec, logger=logger)
# Out:
# Client established
# Collection retrieved
# C:\Users\GANSOR-PC\anaconda3\lib\site-packages\ipykernel_launcher.py:88: DeprecationWarning: initialize_unordered_bulk_op is deprecated
# Image2vec instance created
# started
# 0 start
# 0 added_embeddings
# 0 updated
# 10 Total elapsed time: 117.39546942710876
# 10 Documents processed: 1
# 1 start
# 1 added_embeddings
# 1 updated
# 10 Total elapsed time: 118.12850952148438
# 10 Documents processed: 2
# 2 start
# 2 added_embeddings
# 2 updated
# 10 Total elapsed time: 118.83860993385315
# 10 Documents processed: 3
# 3 start
# 3 added_embeddings
# 3 updated
# 10 Total elapsed time: 119.56068015098572
# 10 Documents processed: 4
# 4 start
# 4 added_embeddings
# 4 updated
# 10 Total elapsed time: 120.30170130729675
# 10 Documents processed: 5
# 5 start
# 5 added_embeddings
# 5 updated
# 10 Total elapsed time: 121.02975368499756
# 10 Documents processed: 6
# 6 start
# 6 added_embeddings
# 6 updated
# 10 Total elapsed time: 121.75581216812134
# 10 Documents processed: 7
# 7 start
# 7 added_embeddings
# 7 updated
# 10 Total elapsed time: 122.47090220451355
# 10 Documents processed: 8
# 8 start
# 8 added_embeddings
# 8 updated
# 10 Total elapsed time: 122.53672480583191
# 10 Documents processed: 9
# 9 start
# 9 added_embeddings
# 9 updated
# 10 Total elapsed time: 123.28173446655273
# 10 Documents processed: 10
# 10 start
# 10 added_embeddings
# 10 updated
# 10 Total elapsed time: 124.00280666351318
# 10 Documents processed: 11
# 11 start
# 11 added_embeddings
# 11 updated
# 10 Total elapsed time: 124.70592713356018
# 10 Documents processed: 12
# 12 start
# 12 added_embeddings
# 12 updated
# 10 Total elapsed time: 125.43897819519043
# 10 Documents processed: 13
# 13 start
# 13 added_embeddings
# 13 updated
# 10 Total elapsed time: 126.15904378890991
# 10 Documents processed: 14
# 14 start
# 14 added_embeddings
# 14 updated
# 10 Total elapsed time: 126.88809585571289
# 10 Documents processed: 15
# 15 start
# 15 added_embeddings
# 15 updated
# 10 Total elapsed time: 127.61315631866455
# 10 Documents processed: 16
# 16 start
# 16 added_embeddings
# 16 updated
# 10 Total elapsed time: 127.9961326122284
# 10 Documents processed: 17
# 17 start
# 17 added_embeddings
# 17 updated
# 10 Total elapsed time: 128.7112214565277
# 10 Documents processed: 18
# 18 start
# 18 added_embeddings
# 18 updated
# 10 Total elapsed time: 129.42232084274292
# 10 Documents processed: 19
# 19 start
# 19 added_embeddings
# 19 updated
# 10 Total elapsed time: 130.1384072303772
# 10 Documents processed: 20
# 20 start
# 20 added_embeddings
# 20 updated
# 10 Total elapsed time: 130.8554916381836
# 10 Documents processed: 21
# 21 start
# 21 added_embeddings
# 21 updated
# 10 Total elapsed time: 131.44291973114014
# 10 Documents processed: 22
# 22 start
# 22 added_embeddings
# 22 updated
# 10 Total elapsed time: 132.15403413772583
# 10 Documents processed: 23
# 23 start
# 23 added_embeddings
# 23 updated
# 10 Total elapsed time: 132.86910843849182
# 10 Documents processed: 24
# 24 start
# 24 added_embeddings
# 24 updated
# 10 Total elapsed time: 133.59815907478333
# 10 Documents processed: 25
# 25 start
# 25 added_embeddings
# 25 updated
# 10 Total elapsed time: 134.32022905349731
# 10 Documents processed: 26
# 26 start
# 26 added_embeddings
# 26 updated
# 10 Total elapsed time: 134.85180807113647
# 10 Documents processed: 27
# 27 start
# 27 added_embeddings
# 27 updated
# 10 Total elapsed time: 135.5678951740265
# 10 Documents processed: 28
# 28 start
# 28 added_embeddings
# 28 updated
# 10 Total elapsed time: 136.31090807914734
# 10 Documents processed: 29
# 29 start
# 29 added_embeddings
# 29 updated
# 10 Total elapsed time: 137.02699613571167
# 10 Documents processed: 30
# 30 start
# 30 added_embeddings
# 30 updated
# 10 Total elapsed time: 137.74407815933228
# 10 Documents processed: 31
# 31 start
# 31 added_embeddings
# 31 updated
# 10 Total elapsed time: 138.46913933753967
# 10 Documents processed: 32
# 32 start
# 32 added_embeddings
# 32 updated
# 10 Total elapsed time: 139.18023872375488
# 10 Documents processed: 33
# 33 start
# 33 added_embeddings
# 33 updated
# 10 Total elapsed time: 139.90629839897156
# 10 Documents processed: 34
# 34 start
# 34 added_embeddings
# 34 updated
# 10 Total elapsed time: 140.64033675193787
# 10 Documents processed: 35
# 35 start
# 35 added_embeddings
# 35 updated
# 10 Total elapsed time: 141.37138271331787
# 10 Documents processed: 36
# 36 start
# 36 added_embeddings
# 36 updated
# 10 Total elapsed time: 142.108412027359
# 10 Documents processed: 37
# 37 start
# 37 added_embeddings
# 37 updated
# 10 Total elapsed time: 142.8155219554901
# 10 Documents processed: 38
# 38 start
# 38 added_embeddings
# 38 updated
# 10 Total elapsed time: 143.54956150054932
# 10 Documents processed: 39
# 39 start
# 39 added_embeddings
# 39 updated
# 10 Total elapsed time: 144.25966358184814
# 10 Documents processed: 40
# 40 start
# 40 added_embeddings
# 40 updated
# 10 Total elapsed time: 144.5239553451538
# 10 Documents processed: 41
# 41 start
# 41 added_embeddings
# 41 updated
# 10 Total elapsed time: 145.2520091533661
# 10 Documents processed: 42
# 42 start
# 42 added_embeddings
# 42 updated
# 10 Total elapsed time: 145.9860498905182
# 10 Documents processed: 43
# 43 start
# 43 added_embeddings
# 43 updated
# 10 Total elapsed time: 146.74402260780334
# 10 Documents processed: 44
# 44 start
# 44 added_embeddings
# 44 updated
# 10 Total elapsed time: 147.49301934242249
# 10 Documents processed: 45
# 45 start
# 45 added_embeddings
# 45 updated
# 10 Total elapsed time: 148.22007632255554
# 10 Documents processed: 46
# 46 start
# 46 added_embeddings
# 46 updated
# 10 Total elapsed time: 148.95511102676392
# 10 Documents processed: 47
# 47 start
# 47 added_embeddings
# 47 updated
# 10 Total elapsed time: 149.63030886650085
# 10 Documents processed: 48
# 48 start
# 48 added_embeddings
# 48 updated
# 10 Total elapsed time: 150.3813033103943
# 10 Documents processed: 49
# 49 start
# 49 added_embeddings
# 49 updated
# 10 Total elapsed time: 151.11832904815674
# 10 Documents processed: 50
# 50 start
# 50 added_embeddings
# 50 updated
# 10 Total elapsed time: 151.18614768981934
# 10 Documents processed: 51
# 51 start
# 51 added_embeddings
# 51 updated
# 10 Total elapsed time: 151.92118334770203
# 10 Documents processed: 52
# 52 start
# 52 added_embeddings
# 52 updated
# 10 Total elapsed time: 152.65721583366394
# 10 Documents processed: 53
# 53 start
# 53 added_embeddings
# 53 updated
# 10 Total elapsed time: 153.3972384929657
# 10 Documents processed: 54
# 54 start
# 54 added_embeddings
# 54 updated
# 10 Total elapsed time: 154.14324498176575
# 10 Documents processed: 55
# 55 start
# 55 added_embeddings
# 55 updated
# 10 Total elapsed time: 154.877281665802
# 10 Documents processed: 56
# 56 start
# 56 added_embeddings
# 56 updated
# 10 Total elapsed time: 155.60334610939026
# 10 Documents processed: 57
# 57 start
# 57 added_embeddings
# 57 updated
# 10 Total elapsed time: 156.32940101623535
# 10 Documents processed: 58
# 58 start
# 58 added_embeddings
# 58 updated
# 10 Total elapsed time: 157.02554178237915
# 10 Documents processed: 59
# 59 start
# 59 added_embeddings
# 59 updated
# 10 Total elapsed time: 157.69973850250244
# 10 Documents processed: 60
# 60 start
# 60 added_embeddings
# 60 updated
# 10 Total elapsed time: 158.42878913879395
# 10 Documents processed: 61
# 61 start
# 61 added_embeddings
# 61 updated
# 10 Total elapsed time: 159.16581892967224
# 10 Documents processed: 62
# 62 start
# 62 added_embeddings
# 62 updated
# 10 Total elapsed time: 159.88290214538574
# 10 Documents processed: 63
# 63 start
# 63 added_embeddings
# 63 updated
# 10 Total elapsed time: 160.60297751426697
# 10 Documents processed: 64
# 64 start
# 64 added_embeddings
# 64 updated
# 10 Total elapsed time: 161.31507468223572
# 10 Documents processed: 65
# 65 start
# 65 added_embeddings
# 65 updated
# 10 Total elapsed time: 162.02816796302795
# 10 Documents processed: 66
# 66 start
# 66 added_embeddings
# 66 updated
# 10 Total elapsed time: 162.75323152542114
# 10 Documents processed: 67
# 67 start
# 67 added_embeddings
# 67 updated
# 10 Total elapsed time: 163.46732115745544
# 10 Documents processed: 68
# 68 start
# 68 added_embeddings
# 68 updated
# 10 Total elapsed time: 164.18640065193176
# 10 Documents processed: 69
# 69 start
# 69 added_embeddings
# 69 updated
# 10 Total elapsed time: 164.89949345588684
# 10 Documents processed: 70
# 70 start
# 70 added_embeddings
# 70 updated
# 10 Total elapsed time: 165.61258721351624
# 10 Documents processed: 71
# 71 start
# 71 added_embeddings
# 71 updated
# 10 Total elapsed time: 166.3326632976532
# 10 Documents processed: 72
# 72 start
# 72 added_embeddings
# 72 updated
# 10 Total elapsed time: 167.06570267677307
# 10 Documents processed: 73
# 73 start
# 73 added_embeddings
# 73 updated
# 10 Total elapsed time: 167.79974126815796
# 10 Documents processed: 74
# 74 start
# 74 added_embeddings
# 74 updated
# 10 Total elapsed time: 168.51682567596436
# 10 Documents processed: 75
# 75 start
# 75 added_embeddings
# 75 updated
# 10 Total elapsed time: 169.23889470100403
# 10 Documents processed: 76
# 76 start
# 76 added_embeddings
# 76 updated
# 10 Total elapsed time: 169.69667148590088
# 10 Documents processed: 77
# 77 start
# 77 added_embeddings
# 77 updated
# 10 Total elapsed time: 170.42373037338257
# 10 Documents processed: 78
# 78 start
# 78 added_embeddings
# 78 updated
# 10 Total elapsed time: 170.48955154418945
# 10 Documents processed: 79
# 79 start
# 79 added_embeddings
# 79 updated
# 10 Total elapsed time: 171.22259211540222
# 10 Documents processed: 80
# 80 start
# 80 added_embeddings
# 80 updated
# 10 Total elapsed time: 171.9596221446991
# 10 Documents processed: 81
# 81 start
# 81 added_embeddings
# 81 updated
# 10 Total elapsed time: 172.686678647995
# 10 Documents processed: 82
# 82 start
# 82 added_embeddings
# 82 updated
# 10 Total elapsed time: 173.40276455879211
# 10 Documents processed: 83
# 83 start
# 83 added_embeddings
# 83 updated
# 10 Total elapsed time: 174.124835729599
# 10 Documents processed: 84
# 84 start
# 84 added_embeddings
# 84 updated
# 10 Total elapsed time: 174.8379294872284
# 10 Documents processed: 85
# 85 start
# 85 added_embeddings
# 85 updated
# 10 Total elapsed time: 174.9007604122162
# 10 Documents processed: 86
# 86 start
# 86 added_embeddings
# 86 updated
# 10 Total elapsed time: 175.63280415534973
# 10 Documents processed: 87
# 87 start
# 87 added_embeddings
# 87 updated
# 10 Total elapsed time: 176.3478922843933
# 10 Documents processed: 88
# 88 start
# 88 added_embeddings
# 88 updated
# 10 Total elapsed time: 176.41670846939087
# 10 Documents processed: 89
# 89 start
# 89 added_embeddings
# 89 updated
# 10 Total elapsed time: 176.72987127304077
# 10 Documents processed: 90
# 90 start
# 90 added_embeddings
# 90 updated
# 10 Total elapsed time: 177.45493459701538
# 10 Documents processed: 91
# 91 start
# 91 added_embeddings
# 91 updated
# 10 Total elapsed time: 178.19395923614502
# 10 Documents processed: 92
# 92 start
# 92 added_embeddings
# 92 updated
# 10 Total elapsed time: 178.93198657035828
# 10 Documents processed: 93
# 93 start
# 93 added_embeddings
# 93 updated
# 10 Total elapsed time: 179.65804815292358
# 10 Documents processed: 94
# 94 start
# 94 added_embeddings
# 94 updated
# 10 Total elapsed time: 179.93131470680237
# 10 Documents processed: 95
# 95 start
# 95 added_embeddings
# 95 updated
# 10 Total elapsed time: 180.65538096427917
# 10 Documents processed: 96
# 96 start
# 96 added_embeddings
# 96 updated
# 10 Total elapsed time: 181.3854274749756
# 10 Documents processed: 97
# 97 start
# 97 added_embeddings
# 97 updated
# 10 Total elapsed time: 182.1035087108612
# 10 Documents processed: 98
# 98 start
# 98 added_embeddings
# 98 updated
# 10 Total elapsed time: 182.80662894248962
# 10 Documents processed: 99
# 99 start
# 99 added_embeddings
# 99 updated
# executed bulk
# 30 Total elapsed time: 210.84204983711243
# 30 Documents processed: 100
# 100 start
# 100 added_embeddings
# 100 updated
# 10 Total elapsed time: 211.56611585617065
# 10 Documents processed: 101
# 101 start
# 101 added_embeddings
# 101 updated
# 10 Total elapsed time: 344.2394948005676
# 10 Documents processed: 102
# 102 start
# 102 added_embeddings
# 102 updated
# 10 Total elapsed time: 344.94261622428894
# 10 Documents processed: 103
# 103 start
# 103 added_embeddings
# 103 updated
# 10 Total elapsed time: 345.33057975769043
# 10 Documents processed: 104
# 104 start
# 104 added_embeddings
# 104 updated
# 10 Total elapsed time: 346.0576345920563
# 10 Documents processed: 105
# 105 start
# 105 added_embeddings
# 105 updated
# 10 Total elapsed time: 346.75178050994873
# 10 Documents processed: 106
# 106 start
# 106 added_embeddings
# 106 updated
# 10 Total elapsed time: 347.4239852428436
# 10 Documents processed: 107
# 107 start
# 107 added_embeddings
# 107 updated
# 10 Total elapsed time: 348.14006996154785
# 10 Documents processed: 108
# 108 start
# 108 added_embeddings
# 108 updated
# 10 Total elapsed time: 348.8451850414276
# 10 Documents processed: 109
# 109 start
# 109 added_embeddings
# 109 updated
# 10 Total elapsed time: 349.55428886413574
# 10 Documents processed: 110
# 110 start
# 110 added_embeddings
# 110 updated
# 10 Total elapsed time: 350.2604010105133
# 10 Documents processed: 111
# 111 start
# 111 added_embeddings
# 111 updated
# 10 Total elapsed time: 350.97848176956177
# 10 Documents processed: 112
# 112 start
# 112 added_embeddings
# 112 updated
# 10 Total elapsed time: 351.67063164711
# 10 Documents processed: 113
# 113 start
# 113 added_embeddings
# 113 updated
# 10 Total elapsed time: 352.3348581790924
# 10 Documents processed: 114
# 114 start
# 114 added_embeddings
# 114 updated
# 10 Total elapsed time: 352.97813868522644
# 10 Documents processed: 115
# 115 start
# 115 added_embeddings
# 115 updated
# 10 Total elapsed time: 353.41995573043823
# 10 Documents processed: 116
# 116 start
# 116 added_embeddings
# 116 updated
# 10 Total elapsed time: 354.1141004562378
# 10 Documents processed: 117
# 117 start
# 117 added_embeddings
# 117 updated
# 10 Total elapsed time: 354.78331184387207
# 10 Documents processed: 118
# 118 start
# 118 added_embeddings
# 118 updated
# 10 Total elapsed time: 354.8501350879669
# 10 Documents processed: 119
# 119 start
# 119 added_embeddings
# 119 updated
# 10 Total elapsed time: 355.54627227783203
# 10 Documents processed: 120
# 120 start
# 120 added_embeddings
# 120 updated
# 10 Total elapsed time: 356.2493939399719
# 10 Documents processed: 121
# 121 start
# 121 added_embeddings
# 121 updated
# 10 Total elapsed time: 356.9525136947632
# 10 Documents processed: 122
# 122 start
# 122 added_embeddings
# 122 updated
# 10 Total elapsed time: 357.6217255592346
# 10 Documents processed: 123
# 123 start
# 123 added_embeddings
# 123 updated
# 10 Total elapsed time: 358.3039026260376
# 10 Documents processed: 124
# 124 start
# 124 added_embeddings
# 124 updated
# 10 Total elapsed time: 358.9830856323242
# 10 Documents processed: 125
# 125 start
# 125 added_embeddings
# 125 updated
# 10 Total elapsed time: 359.65828251838684
# 10 Documents processed: 126
# 126 start
# 126 added_embeddings
# 126 updated
# 10 Total elapsed time: 359.9714460372925
# 10 Documents processed: 127
# 127 start
# 127 added_embeddings
# 127 updated
# 10 Total elapsed time: 360.6685824394226
# 10 Documents processed: 128
# 128 start
# 128 added_embeddings
# 128 updated
# 10 Total elapsed time: 361.3717031478882
# 10 Documents processed: 129
# 129 start
# 129 added_embeddings
# 129 updated
# 10 Total elapsed time: 361.8673770427704
# 10 Documents processed: 130
# 130 start
# 130 added_embeddings
# 130 updated
# 10 Total elapsed time: 362.5575339794159
# 10 Documents processed: 131
# 131 start
# 131 added_embeddings
# 131 updated
# 10 Total elapsed time: 363.2616512775421
# 10 Documents processed: 132
# 132 start
# 132 added_embeddings
# 132 updated
# 10 Total elapsed time: 363.95680499076843
# 10 Documents processed: 133
# 133 start
# 133 added_embeddings
# 133 updated
# 10 Total elapsed time: 364.53225541114807
# 10 Documents processed: 134
# 134 start
# 134 added_embeddings
# 134 updated
# 10 Total elapsed time: 365.22440338134766
# 10 Documents processed: 135
# 135 start
# 135 added_embeddings
# 135 updated
# 10 Total elapsed time: 365.8676838874817
# 10 Documents processed: 136
# 136 start
# 136 added_embeddings
# 136 updated
# 10 Total elapsed time: 366.5358998775482
# 10 Documents processed: 137
# 137 start
# 137 added_embeddings
# 137 updated
# 10 Total elapsed time: 367.16122817993164
# 10 Documents processed: 138
# 138 start
# 138 added_embeddings
# 138 updated
# 10 Total elapsed time: 367.86833667755127
# 10 Documents processed: 139
# 139 start
# 139 added_embeddings
# 139 updated
# 10 Total elapsed time: 368.5405492782593
# 10 Documents processed: 140
# 140 start
# 140 added_embeddings
# 140 updated
# 10 Total elapsed time: 369.21174597740173
# 10 Documents processed: 141
# 141 start
# 141 added_embeddings
# 141 updated
# 10 Total elapsed time: 369.88993430137634
# 10 Documents processed: 142
# 142 start
# 142 added_embeddings
# 142 updated
# 10 Total elapsed time: 370.5810959339142
# 10 Documents processed: 143
# 143 start
# 143 added_embeddings
# 143 updated
# 10 Total elapsed time: 371.27523040771484
# 10 Documents processed: 144
# 144 start
# 144 added_embeddings
# 144 updated
# 10 Total elapsed time: 371.8776226043701
# 10 Documents processed: 145
# 145 start
# 145 added_embeddings
# 145 updated
# 10 Total elapsed time: 372.5498237609863
# 10 Documents processed: 146
# 146 start
# 146 added_embeddings
# 146 updated
# 10 Total elapsed time: 373.116308927536
# 10 Documents processed: 147
# 147 start
# 147 added_embeddings
# 147 updated
# 10 Total elapsed time: 373.76756954193115
# 10 Documents processed: 148
# 148 start
# 148 added_embeddings
# 148 updated
# 10 Total elapsed time: 374.46470618247986
# 10 Documents processed: 149
# 149 start
# 149 added_embeddings
# 149 updated
# 10 Total elapsed time: 375.1658310890198
# 10 Documents processed: 150
# 150 start
# 150 added_embeddings
# 150 updated
# 10 Total elapsed time: 375.867956161499
# 10 Documents processed: 151
# 151 start
# 151 added_embeddings
# 151 updated
# 10 Total elapsed time: 376.54414916038513
# 10 Documents processed: 152
# 152 start
# 152 added_embeddings
# 152 updated
# 10 Total elapsed time: 377.18742775917053
# 10 Documents processed: 153
# 153 start
# 153 added_embeddings
# 153 updated
# 10 Total elapsed time: 377.83469796180725
# 10 Documents processed: 154
# 154 start
# 154 added_embeddings
# 154 updated
# 10 Total elapsed time: 378.4919424057007
# 10 Documents processed: 155
# 155 start
# 155 added_embeddings
# 155 updated
# 10 Total elapsed time: 379.12125968933105
# 10 Documents processed: 156
# 156 start
# 156 added_embeddings
# 156 updated
# 10 Total elapsed time: 379.7336232662201
# 10 Documents processed: 157
# 157 start
# 157 added_embeddings
# 157 updated
# 10 Total elapsed time: 380.37291502952576
# 10 Documents processed: 158
# 158 start
# 2020-06-20 01:11:13,693 - ERROR - output with shape [1, 224, 224] doesn't match the broadcast shape [3, 224, 224]
# Traceback (most recent call last):
#   File "<ipython-input-10-ad55386d0a82>", line 109, in vectorize_images
#     add_embeddings(img2vec, profile)
#   File "<ipython-input-10-ad55386d0a82>", line 46, in add_embeddings
#     profile[profile_pic_embedding] = img2vec.apply_single(to_pil(profile[profile_pic]))
#   File "../img2vec\img2vec.py", line 22, in apply_single
#     image_tensor = self.normalize(self.to_tensor(self.scaler(img))).unsqueeze(0).to(self.device)
#   File "C:\Users\GANSOR-PC\anaconda3\lib\site-packages\torchvision\transforms\transforms.py", line 166, in __call__
#     return F.normalize(tensor, self.mean, self.std, self.inplace)
#   File "C:\Users\GANSOR-PC\anaconda3\lib\site-packages\torchvision\transforms\functional.py", line 208, in normalize
#     tensor.sub_(mean).div_(std)
# RuntimeError: output with shape [1, 224, 224] doesn't match the broadcast shape [3, 224, 224]
# 2020-06-20 01:11:13,693 - ERROR - output with shape [1, 224, 224] doesn't match the broadcast shape [3, 224, 224]
# Traceback (most recent call last):
#   File "<ipython-input-10-ad55386d0a82>", line 109, in vectorize_images
#     add_embeddings(img2vec, profile)
#   File "<ipython-input-10-ad55386d0a82>", line 46, in add_embeddings
#     profile[profile_pic_embedding] = img2vec.apply_single(to_pil(profile[profile_pic]))
#   File "../img2vec\img2vec.py", line 22, in apply_single
#     image_tensor = self.normalize(self.to_tensor(self.scaler(img))).unsqueeze(0).to(self.device)
#   File "C:\Users\GANSOR-PC\anaconda3\lib\site-packages\torchvision\transforms\transforms.py", line 166, in __call__
#     return F.normalize(tensor, self.mean, self.std, self.inplace)
#   File "C:\Users\GANSOR-PC\anaconda3\lib\site-packages\torchvision\transforms\functional.py", line 208, in normalize
#     tensor.sub_(mean).div_(std)
# RuntimeError: output with shape [1, 224, 224] doesn't match the broadcast shape [3, 224, 224]
# 2020-06-20 01:11:13,693 - ERROR - output with shape [1, 224, 224] doesn't match the broadcast shape [3, 224, 224]
# Traceback (most recent call last):
#   File "<ipython-input-10-ad55386d0a82>", line 109, in vectorize_images
#     add_embeddings(img2vec, profile)
#   File "<ipython-input-10-ad55386d0a82>", line 46, in add_embeddings
#     profile[profile_pic_embedding] = img2vec.apply_single(to_pil(profile[profile_pic]))
#   File "../img2vec\img2vec.py", line 22, in apply_single
#     image_tensor = self.normalize(self.to_tensor(self.scaler(img))).unsqueeze(0).to(self.device)
#   File "C:\Users\GANSOR-PC\anaconda3\lib\site-packages\torchvision\transforms\transforms.py", line 166, in __call__
#     return F.normalize(tensor, self.mean, self.std, self.inplace)
#   File "C:\Users\GANSOR-PC\anaconda3\lib\site-packages\torchvision\transforms\functional.py", line 208, in normalize
#     tensor.sub_(mean).div_(std)
# RuntimeError: output with shape [1, 224, 224] doesn't match the broadcast shape [3, 224, 224]
# 2020-06-20 01:11:13,693 - ERROR - output with shape [1, 224, 224] doesn't match the broadcast shape [3, 224, 224]
# Traceback (most recent call last):
#   File "<ipython-input-10-ad55386d0a82>", line 109, in vectorize_images
#     add_embeddings(img2vec, profile)
#   File "<ipython-input-10-ad55386d0a82>", line 46, in add_embeddings
#     profile[profile_pic_embedding] = img2vec.apply_single(to_pil(profile[profile_pic]))
#   File "../img2vec\img2vec.py", line 22, in apply_single
#     image_tensor = self.normalize(self.to_tensor(self.scaler(img))).unsqueeze(0).to(self.device)
#   File "C:\Users\GANSOR-PC\anaconda3\lib\site-packages\torchvision\transforms\transforms.py", line 166, in __call__
#     return F.normalize(tensor, self.mean, self.std, self.inplace)
#   File "C:\Users\GANSOR-PC\anaconda3\lib\site-packages\torchvision\transforms\functional.py", line 208, in normalize
#     tensor.sub_(mean).div_(std)
# RuntimeError: output with shape [1, 224, 224] doesn't match the broadcast shape [3, 224, 224]
# 158 added_embeddings
# 158 updated
# 10 Total elapsed time: 381.0072250366211
# 10 Documents processed: 159
# 159 start
# 10 Total elapsed time: 381.03414607048035
# 10 Documents processed: 160
# 160 start
# 160 added_embeddings
# 160 updated
# 10 Total elapsed time: 381.73128366470337
# 10 Documents processed: 161
# 161 start
# 161 added_embeddings
# 161 updated
# 10 Total elapsed time: 382.35661220550537
# 10 Documents processed: 162
# 162 start
# 162 added_embeddings
# 162 updated
# 10 Total elapsed time: 383.02285146713257
# 10 Documents processed: 163
# 163 start
# 163 added_embeddings
# 163 updated
# 10 Total elapsed time: 383.6840624809265
# 10 Documents processed: 164
# 164 start
# 164 added_embeddings
# 164 updated
# 10 Total elapsed time: 384.32136034965515
# 10 Documents processed: 165
# 165 start
# 165 added_embeddings
# 165 updated
# 10 Total elapsed time: 384.92574524879456
# 10 Documents processed: 166
# 166 start
# 166 added_embeddings
# 166 updated
# 10 Total elapsed time: 385.5710189342499
# 10 Documents processed: 167
# 167 start
# 167 added_embeddings
# 167 updated
# 10 Total elapsed time: 385.6198914051056
# 10 Documents processed: 168
# 168 start
# 168 added_embeddings
# 168 updated
# 10 Total elapsed time: 386.25219798088074
# 10 Documents processed: 169
# 169 start
# 169 added_embeddings
# 169 updated
# 10 Total elapsed time: 386.91043972969055
# 10 Documents processed: 170
# 170 start
# 170 added_embeddings
# 170 updated
# 10 Total elapsed time: 387.5417523384094
# 10 Documents processed: 171
# 171 start
# 171 added_embeddings
# 171 updated
# 10 Total elapsed time: 388.21694803237915
# 10 Documents processed: 172
# 172 start
# 172 added_embeddings
# 172 updated
# 10 Total elapsed time: 388.8123562335968
# 10 Documents processed: 173
# 173 start
# 173 added_embeddings
# 173 updated
# 10 Total elapsed time: 389.4676032066345
# 10 Documents processed: 174
# 174 start
# 174 added_embeddings
# 174 updated
# 10 Total elapsed time: 390.1248481273651
# 10 Documents processed: 175
# 175 start
# 175 added_embeddings
# 175 updated
# 10 Total elapsed time: 390.7701244354248
# 10 Documents processed: 176
# 176 start
# 176 added_embeddings
# 176 updated
# 10 Total elapsed time: 391.4034297466278
# 10 Documents processed: 177
# 177 start
# 177 added_embeddings
# 177 updated
# 10 Total elapsed time: 392.01679158210754
# 10 Documents processed: 178
# 178 start
# 178 added_embeddings
# 178 updated
# 10 Total elapsed time: 392.68800592422485
# 10 Documents processed: 179
# 179 start
# 179 added_embeddings
# 179 updated
# 10 Total elapsed time: 393.36917662620544
# 10 Documents processed: 180
# 180 start
# 180 added_embeddings
# 180 updated
# 10 Total elapsed time: 394.00747895240784
# 10 Documents processed: 181
# 181 start
# 181 added_embeddings
# 181 updated
# 10 Total elapsed time: 394.66471910476685
# 10 Documents processed: 182
# 182 start
# 182 added_embeddings
# 182 updated
# 10 Total elapsed time: 394.7235562801361
# 10 Documents processed: 183
# 183 start
# 183 added_embeddings
# 183 updated
# 10 Total elapsed time: 395.37082719802856
# 10 Documents processed: 184
# 184 start
# 184 added_embeddings
# 184 updated
# 10 Total elapsed time: 396.0230815410614
# 10 Documents processed: 185
# 185 start
# 185 added_embeddings
# 185 updated
# 10 Total elapsed time: 396.6474142074585
# 10 Documents processed: 186
# 186 start
# 186 added_embeddings
# 186 updated
# 10 Total elapsed time: 397.30465745925903
# 10 Documents processed: 187
# 187 start
# 187 added_embeddings
# 187 updated
# 10 Total elapsed time: 397.96389508247375
# 10 Documents processed: 188
# 188 start
# 188 added_embeddings
# 188 updated
# 10 Total elapsed time: 398.62712121009827
# 10 Documents processed: 189
# 189 start
# 189 added_embeddings
# 189 updated
# 10 Total elapsed time: 399.29733061790466
# 10 Documents processed: 190
# 190 start
# 190 added_embeddings
# 190 updated
# 10 Total elapsed time: 399.8977246284485
# 10 Documents processed: 191
# 191 start
# 191 added_embeddings
# 191 updated
# 10 Total elapsed time: 400.56494402885437
# 10 Documents processed: 192
# 192 start
# 192 added_embeddings
# 192 updated
# 10 Total elapsed time: 401.24013781547546
# 10 Documents processed: 193
# 193 start
# 193 added_embeddings
# 193 updated
# 10 Total elapsed time: 401.8674602508545
# 10 Documents processed: 194
# 194 start
# 194 added_embeddings
# 194 updated
# 10 Total elapsed time: 402.50675082206726
# 10 Documents processed: 195
# 195 start
# 195 added_embeddings
# 195 updated
# 10 Total elapsed time: 403.1500313282013
# 10 Documents processed: 196
# 196 start
# 196 added_embeddings
# 196 updated
# 10 Total elapsed time: 403.76538825035095
# 10 Documents processed: 197
# 197 start
# 197 added_embeddings
# 197 updated
# 10 Total elapsed time: 404.4076714515686
# 10 Documents processed: 198
# 198 start
# 198 added_embeddings
# 198 updated
# 10 Total elapsed time: 518.871262550354
# 10 Documents processed: 199
# 199 start
# 199 added_embeddings
# 199 updated
# executed bulk
# 30 Total elapsed time: 543.5093729496002
# 30 Documents processed: 200
# 200 start
# 200 added_embeddings
# 200 updated
# 10 Total elapsed time: 544.2284510135651
# 10 Documents processed: 201
# 201 start
# 201 added_embeddings
# 201 updated
# 10 Total elapsed time: 544.9445357322693
# 10 Documents processed: 202
# 202 start
# 202 added_embeddings
# 202 updated
# 10 Total elapsed time: 545.6695973873138
# 10 Documents processed: 203
# 203 start
# 203 added_embeddings
# 203 updated
# 10 Total elapsed time: 546.3697271347046
# 10 Documents processed: 204
# 204 start
# 204 added_embeddings
# 204 updated
# 10 Total elapsed time: 547.0888044834137
# 10 Documents processed: 205
# 205 start
# 205 added_embeddings
# 205 updated
# 10 Total elapsed time: 547.8038923740387
# 10 Documents processed: 206
# 206 start
# 206 added_embeddings
# 206 updated
# 10 Total elapsed time: 548.5239810943604
# 10 Documents processed: 207
# 207 start
# 207 added_embeddings
# 207 updated
# 10 Total elapsed time: 549.2380595207214
# 10 Documents processed: 208
# 208 start
# 208 added_embeddings
# 208 updated
# 10 Total elapsed time: 549.2969040870667
# 10 Documents processed: 209
# 209 start
# 209 added_embeddings
# 209 updated
# 10 Total elapsed time: 549.9870569705963
# 10 Documents processed: 210
# 210 start
# 210 added_embeddings
# 210 updated
# 10 Total elapsed time: 550.6562683582306
# 10 Documents processed: 211
# 211 start
# 211 added_embeddings
# 211 updated
# 10 Total elapsed time: 551.3683660030365
# 10 Documents processed: 212
# 212 start
# 212 added_embeddings
# 212 updated
# 10 Total elapsed time: 552.0944247245789
# 10 Documents processed: 213
# 213 start
# 213 added_embeddings
# 213 updated
# 10 Total elapsed time: 552.8055255413055
# 10 Documents processed: 214
# 214 start
# 214 added_embeddings
# 214 updated
# 10 Total elapsed time: 553.5096430778503
# 10 Documents processed: 215
# 215 start
# 215 added_embeddings
# 215 updated
# 10 Total elapsed time: 554.2386932373047
# 10 Documents processed: 216
# 216 start
# 216 added_embeddings
# 216 updated
# 10 Total elapsed time: 554.9597661495209
# 10 Documents processed: 217
# 217 start
# 217 added_embeddings
# 217 updated
# 10 Total elapsed time: 555.7117552757263
# 10 Documents processed: 218
# 218 start
# 218 added_embeddings
# 218 updated
# 10 Total elapsed time: 556.4228556156158
# 10 Documents processed: 219
# 219 start
# 10 Total elapsed time: 556.6851546764374
# 10 Documents processed: 220
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-ad55386d0a82> in <module>
#     151     img2vec = setup_img2vec(logger)
#     152
# --> 153     for_each_profile(do=vectorize_images, profiles=profiles, bulk=bulk, img2vec=img2vec, logger=logger)
#
# <ipython-input-10-ad55386d0a82> in for_each_profile(do, profiles, bulk, img2vec, logger)
#     143
#     144 def for_each_profile(do, profiles, bulk, img2vec, logger):
# --> 145     do(profiles.find(), bulk, img2vec, logger)
#     146
#     147
#
# <ipython-input-10-ad55386d0a82> in vectorize_images(cursor, bulk, img2vec, logger)
#     107         try:
#     108             print(cnt, "start")
# --> 109             add_embeddings(img2vec, profile)
#     110             print(cnt, "added_embeddings")
#     111             bulkList.append(UpdateOne({'_id': profile['_id']},
#
# <ipython-input-10-ad55386d0a82> in add_embeddings(img2vec, profile)
#      49         for post in profile[posts]:
#      50             if image in post:
# ---> 51                 post[image_embedding] = img2vec.apply_single(to_pil(post[image])).tolist()
#      52
#      53
#
# c:\ITMO\instagram-auditor\img2vec\img2vec.py in apply_single(self, img, output)
#      20
#      21     def apply_single(self, img, output=OUTPUT_VECTOR):
# ---> 22         image_tensor = self.normalize(self.to_tensor(self.scaler(img))).unsqueeze(0).to(self.device)
#      23
#      24         tensor_vec = torch.zeros(1, self.emdedding_size, 1, 1)
#
# ~\anaconda3\lib\site-packages\torchvision\transforms\transforms.py in __call__(self, img)
#     196             PIL Image: Rescaled image.
#     197         """
# --> 198         return F.resize(img, self.size, self.interpolation)
#     199
#     200     def __repr__(self):
#
# ~\anaconda3\lib\site-packages\torchvision\transforms\functional.py in resize(img, size, interpolation)
#     244             return img.resize((ow, oh), interpolation)
#     245     else:
# --> 246         return img.resize(size[::-1], interpolation)
#     247
#     248
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in resize(self, size, resample, box, reducing_gap)
#    1856             return im.convert(self.mode)
#    1857
# -> 1858         self.load()
#    1859
#    1860         if reducing_gap is not None and resample != NEAREST:
#
# ~\anaconda3\lib\site-packages\PIL\ImageFile.py in load(self)
#     249
#     250                             b = b + s
# --> 251                             n, err_code = decoder.decode(b)
#     252                             if n < 0:
#     253                                 break
#
# KeyboardInterrupt:

# %%
import torch
from torchvision import models
from torchvision import transforms


torch.device('cuda')
#torch.device(torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu'))
# Out:
# device(type='cuda')
